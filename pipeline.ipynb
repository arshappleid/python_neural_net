# %%
"""
1. Import the libraries.
2. Import the data , of a stock into a data set.
3. Display the closing price , of the stock as a graph.
"""

# %%
import math;
import numpy as np;
import pandas_datareader as dataRead;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt

## deep learning libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
stockName= "TSLA"
startDate = "2021-03-01"  ## yyyy-mm-dd format
endDate = "2022-03-31"
df = pd.DataFrame(dataRead.DataReader(stockName, data_source='yahoo', start=startDate, end=endDate).round(2).reset_index())
df
# Out:
#           Date     High      Low     Open    Close    Volume  Adj Close
# 0   2021-03-01   719.00   685.05   690.11   718.43  27136200     718.43
# 1   2021-03-02   721.11   685.00   718.28   686.44  23732200     686.44
# 2   2021-03-03   700.70   651.71   687.99   653.20  30208000     653.20
# 3   2021-03-04   668.45   600.00   655.80   621.44  65919500     621.44
# 4   2021-03-05   627.84   539.49   626.06   597.95  89396500     597.95
# ..         ...      ...      ...      ...      ...       ...        ...
# 271 2022-03-25  1021.80   997.32  1008.00  1010.64  20677200    1010.64
# 272 2022-03-28  1097.88  1053.60  1065.10  1091.84  34168700    1091.84
# 273 2022-03-29  1114.77  1073.11  1107.99  1099.57  24538300    1099.57
# 274 2022-03-30  1113.95  1084.00  1091.17  1093.99  19955000    1093.99
# 275 2022-03-31  1103.14  1076.64  1094.57  1077.60  16330900    1077.60
#
# [276 rows x 7 columns]

# %%
sns.set(rc = {'figure.figsize':(16,8)})
plot1 = sns.lineplot(x = df.Date , y = df.Close, data= "df" ).set( ylabel = "Close price in USD")
plot1
# Out:
# [Text(0, 0.5, 'Close price in USD')]

# %%
dfm = df.melt('Date', var_name='cols', value_name='vals')
# Out:
# [Text(0, 0.5, 'Close price in USD')]
